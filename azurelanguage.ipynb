# %%
pip install azure-ai-textanalytics
# Out:
# Collecting azure-ai-textanalytics
#   Downloading azure_ai_textanalytics-5.3.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.6/298.6 kB 3.9 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.24.0 (from azure-ai-textanalytics)
#   Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 11.9 MB/s eta 0:00:00
# Collecting azure-common~=1.1 (from azure-ai-textanalytics)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting isodate<1.0.0,>=0.6.1 (from azure-ai-textanalytics)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from azure-ai-textanalytics) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2024.6.2)
# Installing collected packages: azure-common, isodate, azure-core, azure-ai-textanalytics
# Successfully installed azure-ai-textanalytics-5.3.0 azure-common-1.1.28 azure-core-1.30.2 isodate-0.6.1

# %%
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient
AZURE_LANGUAGE_ENDPOINT="https://swamylangcog1.cognitiveservices.azure.com/"
AZURE_LANGUAGE_KEY="d695d54a1a9c410bb74672bd50142c15"


endpoint = os.environ["AZURE_LANGUAGE_ENDPOINT"]
key = os.environ["AZURE_LANGUAGE_KEY"]

text_analytics_client = TextAnalyticsClient(endpoint, AzureKeyCredential(key))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6a0b5b16af21> in <cell line: 8>()
#       6
#       7
# ----> 8 endpoint = os.environ["AZURE_LANGUAGE_ENDPOINT"]
#       9 key = os.environ["AZURE_LANGUAGE_KEY"]
#      10
#
# /usr/lib/python3.10/os.py in __getitem__(self, key)
#     678         except KeyError:
#     679             # raise KeyError with the original key value
# --> 680             raise KeyError(key) from None
#     681         return self.decodevalue(value)
#     682
#
# KeyError: 'AZURE_LANGUAGE_ENDPOINT'

# %%
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

endpoint = "https://swamylangcog1.cognitiveservices.azure.com/"
key = "d695d54a1a9c410bb74672bd50142c15"

text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))

documents = [
    """the king restaruant is very bad """
]


result = text_analytics_client.analyze_sentiment(documents, show_opinion_mining=True)
docs = [doc for doc in result if not doc.is_error]

print("Let's visualize the sentiment of each of these documents")
for idx, doc in enumerate(docs):
    print(f"Document text: {documents[idx]}")
    print(f"Overall sentiment: {doc.sentiment}")
# Out:
# Let's visualize the sentiment of each of these documents
# Document text: the king restaruant is very bad
# Overall sentiment: negative

# %%
import os
import typing
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient



text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))
reviews = [
    """Rahul went to london"""
]

result = text_analytics_client.recognize_entities(reviews)
result = [review for review in result if not review.is_error]
organization_to_reviews: typing.Dict[str, typing.List[str]] = {}

for idx, review in enumerate(result):
    for entity in review.entities:
        print(f"Entity '{entity.text}' has category '{entity.category}'")
        if entity.category == 'Organization':
            organization_to_reviews.setdefault(entity.text, [])
            organization_to_reviews[entity.text].append(reviews[idx])

for organization, reviews in organization_to_reviews.items():
    print(
        "\n\nOrganization '{}' has left us the following review(s): {}".format(
            organization, "\n\n".join(reviews)
        )
    )
# Out:
# Entity 'Rahul' has category 'Person'
# Entity 'london' has category 'Location'

# %%
import os
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient



text_analytics_client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))
documents = [
    """
    Microsoft was founded by Bill Gates with some friends he met at Harvard. One of his friends,
    Steve Ballmer, eventually became CEO after Bill Gates as well. Steve Ballmer eventually stepped
    down as CEO of Microsoft, and was succeeded by Satya Nadella.
    Microsoft originally moved its headquarters to Bellevue, Washington in January 1979, but is now
    headquartered in Redmond.
    """
]

result = text_analytics_client.recognize_linked_entities(documents)
docs = [doc for doc in result if not doc.is_error]

print(
    "Let's map each entity to it's Wikipedia article. I also want to see how many times each "
    "entity is mentioned in a document\n\n"
)
entity_to_url = {}
for doc in docs:
    for entity in doc.entities:
        print("Entity '{}' has been mentioned '{}' time(s)".format(
            entity.name, len(entity.matches)
        ))
        if entity.data_source == "Wikipedia":
            entity_to_url[entity.name] = entity.url
# Out:
# Let's map each entity to it's Wikipedia article. I also want to see how many times each entity is mentioned in a document
#
#
# Entity 'Microsoft' has been mentioned '3' time(s)
# Entity 'Bill Gates' has been mentioned '2' time(s)
# Entity 'Harvard University' has been mentioned '1' time(s)
# Entity 'Steve Ballmer' has been mentioned '2' time(s)
# Entity 'Chief executive officer' has been mentioned '2' time(s)
# Entity 'Satya Nadella' has been mentioned '1' time(s)
# Entity 'Bellevue, Washington' has been mentioned '1' time(s)
# Entity 'Briann January' has been mentioned '1' time(s)
# Entity 'Redmond, Washington' has been mentioned '1' time(s)
